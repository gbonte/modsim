# %%
"""Companion code to https://realpython.com/simulation-with-simpy/

'Simulating Real-World Processes With SimPy'

Python version: 3.7.3
SimPy version: 3.0.11
"""

import simpy
import random
import statistics

wait_times = []
## empty list to hold the wait times 
## Once all the wait times have been appended here, 
## you’ll be able to perform some statistics on this list to determine 
## if you have the proper number of employees or not.


class Theater(object):
    def __init__(self, env, num_cashiers, num_servers, num_ushers):
        self.env = env
        ## simpy environment
        
        self.cashier = simpy.Resource(env, num_cashiers)
        # number of cashiers available to sell tickets to the moviegoers.
        
        self.server = simpy.Resource(env, num_servers)
        self.usher = simpy.Resource(env, num_ushers)

    def purchase_ticket(self, moviegoer):
        yield self.env.timeout(random.randint(1, 3))

    def check_ticket(self, moviegoer):
        yield self.env.timeout(3 / 60)

    def sell_food(self, moviegoer):
        yield self.env.timeout(random.randint(5, 10))


def go_to_movies(moviegoer, theater):
    # Moviegoer arrives at the theater
    env=theater.env
    arrival_time = env.now

    
    # with statement helps avoiding bugs and leaks by ensuring that a resource is properly released 
    # when the code using the resource is completely executed.
    with theater.cashier.request() as request:
        # moviegoer generates a request to use a cashier.
        print('%7.4f : person %s waiting for cashier' % (env.now, moviegoer))
        yield request
        # yield request: moviegoer waits for a cashier to become available if all are currently in use.  
        # When a "yield" statement is hit, the program suspends function execution 
        # and returns the yielded value to the caller.
        
        print('%7.4f : person %s got cashier' % (env.now, moviegoer))
        yield env.process(theater.purchase_ticket(moviegoer))
        print('%7.4f : person %s has purchased the ticket ' % (env.now, moviegoer))

    with theater.usher.request() as request:
        print('%7.4f : person %s waiting for usher' % (env.now, moviegoer))
        yield request
        print('%7.4f : person %s got usher' % (env.now, moviegoer))
        yield env.process(theater.check_ticket(moviegoer))
        print('%7.4f : person %s has checked the ticket ' % (env.now, moviegoer))

    if random.choice([True, False]):
        with theater.server.request() as request:
            print('%7.4f : person %s waiting for food service' % (env.now, moviegoer))
            yield request
            print('%7.4f : person %s is being served food' % (env.now, moviegoer))
            yield env.process(theater.sell_food(moviegoer))
            print('%7.4f : person %s got food ' % (env.now, moviegoer))

    # Moviegoer heads into the theater
    delay=env.now - arrival_time
    wait_times.append(delay)
    print('%7.4f : person %s arrived at %7.4f and heads into the theater after  %7.4f minutes' % (env.now, moviegoer,arrival_time,delay))

def run_theater(env, num_cashiers, num_servers, num_ushers):
    theater = Theater(env, num_cashiers, num_servers, num_ushers)
    
    for moviegoer in range(3):
        env.process(go_to_movies( moviegoer, theater))

    while True:
        yield env.timeout(4.20)  # Wait a bit before generating a new person

        moviegoer += 1
        env.process(go_to_movies( moviegoer, theater))


def get_average_wait_time(wait_times):
    average_wait = statistics.mean(wait_times)
    # Pretty print the results
    minutes, frac_minutes = divmod(average_wait, 1)
    seconds = frac_minutes * 60
    return round(minutes), round(seconds)




def main():
    # Setup
    random.seed(42)
    num_cashiers=1
    num_servers=1
    num_ushers = 3

    # Run the simulation
    env = simpy.Environment()
    env.process(run_theater(env, num_cashiers, num_servers, num_ushers))
    env.run(until=90)

    # View the results
    mins, secs = get_average_wait_time(wait_times)
    print(
        "Running simulation...",
        f"\nThe average wait time is {mins} minutes and {secs} seconds.",
    )


if __name__ == "__main__":
    main()
# Out:
#  4.2000 : person 2 waiting for cashier
#  4.2000 : person 2 got cashier
#  7.2000 : person 2 has purchased the ticket
#  7.2000 : person 2 waiting for usher
#  7.2000 : person 2 got usher
#  7.2500 : person 2 has checked the ticket
#  7.2500 : person 2 waiting for food service
#  7.2500 : person 2 is being served food
#  8.4000 : person 3 waiting for cashier
#  8.4000 : person 3 got cashier
# 11.4000 : person 3 has purchased the ticket
# 11.4000 : person 3 waiting for usher
# 11.4000 : person 3 got usher
# 11.4500 : person 3 has checked the ticket
# 11.4500 : person 3 arrived at  8.4000 and heads into the theater after   3.0500 minutes
# 12.2500 : person 2 got food
# 12.2500 : person 2 arrived at  4.2000 and heads into the theater after   8.0500 minutes
# 12.6000 : person 4 waiting for cashier
# 12.6000 : person 4 got cashier
# 13.6000 : person 4 has purchased the ticket
# 13.6000 : person 4 waiting for usher
# 13.6000 : person 4 got usher
# 13.6500 : person 4 has checked the ticket
# 13.6500 : person 4 waiting for food service
# 13.6500 : person 4 is being served food
# 16.8000 : person 5 waiting for cashier
# 16.8000 : person 5 got cashier
# 19.6500 : person 4 got food
# 19.6500 : person 4 arrived at 12.6000 and heads into the theater after   7.0500 minutes
# 19.8000 : person 5 has purchased the ticket
# 19.8000 : person 5 waiting for usher
# 19.8000 : person 5 got usher
# 19.8500 : person 5 has checked the ticket
# 19.8500 : person 5 waiting for food service
# 19.8500 : person 5 is being served food
# 21.0000 : person 6 waiting for cashier
# 21.0000 : person 6 got cashier
# 24.0000 : person 6 has purchased the ticket
# 24.0000 : person 6 waiting for usher
# 24.0000 : person 6 got usher
# 24.0500 : person 6 has checked the ticket
# 24.0500 : person 6 waiting for food service
# 25.2000 : person 7 waiting for cashier
# 25.2000 : person 7 got cashier
# 28.2000 : person 7 has purchased the ticket
# 28.2000 : person 7 waiting for usher
# 28.2000 : person 7 got usher
# 28.2500 : person 7 has checked the ticket
# 28.2500 : person 7 arrived at 25.2000 and heads into the theater after   3.0500 minutes
# 29.4000 : person 8 waiting for cashier
# 29.4000 : person 8 got cashier
# 29.8500 : person 5 got food
# 29.8500 : person 5 arrived at 16.8000 and heads into the theater after  13.0500 minutes
# 29.8500 : person 6 is being served food
# 30.4000 : person 8 has purchased the ticket
# 30.4000 : person 8 waiting for usher
# 30.4000 : person 8 got usher
# 30.4500 : person 8 has checked the ticket
# 30.4500 : person 8 waiting for food service
# 33.6000 : person 9 waiting for cashier
# 33.6000 : person 9 got cashier
# 34.6000 : person 9 has purchased the ticket
# 34.6000 : person 9 waiting for usher
# 34.6000 : person 9 got usher
# 34.6500 : person 9 has checked the ticket
# 34.6500 : person 9 waiting for food service
# 34.8500 : person 6 got food
# 34.8500 : person 6 arrived at 21.0000 and heads into the theater after  13.8500 minutes
# 34.8500 : person 8 is being served food
# 37.8000 : person 10 waiting for cashier
# 37.8000 : person 10 got cashier
# 40.8000 : person 10 has purchased the ticket
# 40.8000 : person 10 waiting for usher
# 40.8000 : person 10 got usher
# 40.8500 : person 10 has checked the ticket
# 40.8500 : person 10 waiting for food service
# 42.0000 : person 11 waiting for cashier
# 42.0000 : person 11 got cashier
# 43.8500 : person 8 got food
# 43.8500 : person 8 arrived at 29.4000 and heads into the theater after  14.4500 minutes
# 43.8500 : person 9 is being served food
# 45.0000 : person 11 has purchased the ticket
# 45.0000 : person 11 waiting for usher
# 45.0000 : person 11 got usher
# 45.0500 : person 11 has checked the ticket
# 45.0500 : person 11 arrived at 42.0000 and heads into the theater after   3.0500 minutes
# 46.2000 : person 12 waiting for cashier
# 46.2000 : person 12 got cashier
# 47.2000 : person 12 has purchased the ticket
# 47.2000 : person 12 waiting for usher
# 47.2000 : person 12 got usher
# 47.2500 : person 12 has checked the ticket
# 47.2500 : person 12 arrived at 46.2000 and heads into the theater after   1.0500 minutes
# 49.8500 : person 9 got food
# 49.8500 : person 9 arrived at 33.6000 and heads into the theater after  16.2500 minutes
# 49.8500 : person 10 is being served food
# 50.4000 : person 13 waiting for cashier
# 50.4000 : person 13 got cashier
# 52.4000 : person 13 has purchased the ticket
# 52.4000 : person 13 waiting for usher
# 52.4000 : person 13 got usher
# 52.4500 : person 13 has checked the ticket
# 52.4500 : person 13 waiting for food service
# 54.6000 : person 14 waiting for cashier
# 54.6000 : person 14 got cashier
# 55.6000 : person 14 has purchased the ticket
# 55.6000 : person 14 waiting for usher
# 55.6000 : person 14 got usher
# 55.6500 : person 14 has checked the ticket
# 55.6500 : person 14 arrived at 54.6000 and heads into the theater after   1.0500 minutes
# 58.8000 : person 15 waiting for cashier
# 58.8000 : person 15 got cashier
# 58.8500 : person 10 got food
# 58.8500 : person 10 arrived at 37.8000 and heads into the theater after  21.0500 minutes
# 58.8500 : person 13 is being served food
# 60.8000 : person 15 has purchased the ticket
# 60.8000 : person 15 waiting for usher
# 60.8000 : person 15 got usher
# 60.8500 : person 15 has checked the ticket
# 60.8500 : person 15 waiting for food service
# 63.0000 : person 16 waiting for cashier
# 63.0000 : person 16 got cashier
# 64.0000 : person 16 has purchased the ticket
# 64.0000 : person 16 waiting for usher
# 64.0000 : person 16 got usher
# 64.0500 : person 16 has checked the ticket
# 64.0500 : person 16 arrived at 63.0000 and heads into the theater after   1.0500 minutes
# 65.8500 : person 13 got food
# 65.8500 : person 13 arrived at 50.4000 and heads into the theater after  15.4500 minutes
# 65.8500 : person 15 is being served food
# 67.2000 : person 17 waiting for cashier
# 67.2000 : person 17 got cashier
# 68.2000 : person 17 has purchased the ticket
# 68.2000 : person 17 waiting for usher
# 68.2000 : person 17 got usher
# 68.2500 : person 17 has checked the ticket
# 68.2500 : person 17 arrived at 67.2000 and heads into the theater after   1.0500 minutes
# 70.8500 : person 15 got food
# 70.8500 : person 15 arrived at 58.8000 and heads into the theater after  12.0500 minutes
# 71.4000 : person 18 waiting for cashier
# 71.4000 : person 18 got cashier
# 72.4000 : person 18 has purchased the ticket
# 72.4000 : person 18 waiting for usher
# 72.4000 : person 18 got usher
# 72.4500 : person 18 has checked the ticket
# 72.4500 : person 18 arrived at 71.4000 and heads into the theater after   1.0500 minutes
# 75.6000 : person 19 waiting for cashier
# 75.6000 : person 19 got cashier
# 77.6000 : person 19 has purchased the ticket
# 77.6000 : person 19 waiting for usher
# 77.6000 : person 19 got usher
# 77.6500 : person 19 has checked the ticket
# 77.6500 : person 19 arrived at 75.6000 and heads into the theater after   2.0500 minutes
# 79.8000 : person 20 waiting for cashier
# 79.8000 : person 20 got cashier
# 80.8000 : person 20 has purchased the ticket
# 80.8000 : person 20 waiting for usher
# 80.8000 : person 20 got usher
# 80.8500 : person 20 has checked the ticket
# 80.8500 : person 20 arrived at 79.8000 and heads into the theater after   1.0500 minutes
# 84.0000 : person 21 waiting for cashier
# 84.0000 : person 21 got cashier
# 87.0000 : person 21 has purchased the ticket
# 87.0000 : person 21 waiting for usher
# 87.0000 : person 21 got usher
# 87.0500 : person 21 has checked the ticket
# 87.0500 : person 21 waiting for food service
# 87.0500 : person 21 is being served food
# 88.2000 : person 22 waiting for cashier
# 88.2000 : person 22 got cashier
# 89.2000 : person 22 has purchased the ticket
# 89.2000 : person 22 waiting for usher
# 89.2000 : person 22 got usher
# 89.2500 : person 22 has checked the ticket
# 89.2500 : person 22 arrived at 88.2000 and heads into the theater after   1.0500 minutes
# Running simulation...
# The average wait time is 6 minutes and 59 seconds.
